# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
net_res1 = np.load('dataset\Monte_Carlo_Simulation_1000.npz')
net_res2 = np.load('dataset\MC_Simulation_std_025_samples_1000_01_09-21_19.npz')
net_res3 = np.load('dataset\MC_Simulation_std_05_samples_1000_01_09-22_34.npz')

# %%
t = np.arange(144)
i = 5
bar = 15
plt.figure(figsize = (13,4.5), dpi = 300)
plt.plot(t,net_res1["voltages"][(i*144):((i*144)+144), bar], 'y', label = 'Predictions')
plt.show
plt.xticks(np.arange(0, 145, 12), ('0h', '2h', '4h', '6h', '8h', '10h', '12h', '14h','16h', '18h', '20h', '22h', '24h'))
plt.ylim(0.8, 1.05)
plt.title(f'Voltage Bar{bar} - Day {i} - With P/Q as Input')
plt.legend(loc='upper right', prop={'size': 10}, framealpha=1)
plt.plot()
# Out:
# []

# %%
N = 15
net_res1["voltages"].plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\kaioh\Documents\Universidade\State Estimation\comparing_two_datasets.ipynb Célula: 3 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kaioh/Documents/Universidade/State%20Estimation/comparing_two_datasets.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> N = 15
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kaioh/Documents/Universidade/State%20Estimation/comparing_two_datasets.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> net_res1["voltages"].plot()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
# Out:
# (144, 1000, 42)
